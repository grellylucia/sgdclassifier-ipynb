# %%
import numpy as np
import pandas as pd
import modSpellChecker as sc
from contractions import CONTRACTION_MAP
import re
import nltk
import string
from nltk.stem import WordNetLemmatizer
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import gensim
from gensim.models import Word2Vec
from gensim import models
from pattern.en import tag
from nltk.corpus import wordnet as wn
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from gensim import corpora, models
from normalization import normalize_corpus
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.datasets import fetch_20newsgroups
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn.naive_bayes import MultinomialNB

# %%
dataset = pd.read_csv('dataartikel.csv')
dataset
# Out:
#                                                   Judul  \
# 0                         Rupiah masih rawan bergejolak
# 1     SRC sasar ritel tradisional jadi pilar ekonomi...
# 2              Kiat memaksimalkan Facebook untuk bisnis
# 3                           Kiat menambah relasi bisnis
# 4                         Prinsip dasar merintis bisnis
# 5                        10 Sektor seret pelemahan IHSG
# 6                      8 Sektor perkasa lambungkan IHSG
# 7     Untung rugi ratifikasi tujuh perjanjian dagang...
# 8     Uang muka KPR nol persen untuk PNS pada tahun ...
# 9     Cari untung lewat obligasi negara atau deposit...
# 10    Peringatan sensor posisi 737 Max dan pukulan b...
# 11        Cara memastikan investasi tetap sesuai tujuan
# 12    Investor dan pebisnis tak perlu mengkhawatirka...
# 13    Menjaring investor kecil dengan surat utang ritel
# 14    Realisasi investasi melambat menjelang tahun p...
# 15            OJK ungkap 20 perusahaan investasi bodong
# 16             Bermain emas lebih mujur ketimbang valas
# 17        Realisasi investasi migas meleset dari target
# 18    Gaet investor kecil, Bursa akan turunkan satua...
# 19          Toyota suntik Grab dengan uang Rp14 triliun
# 20    Teror bom diyakini tak berpengaruh terhadap ek...
# 21              Milenial pun tak lagi ragu berinvestasi
# 22    Raih dana Rp58 triliun, Inalum siap tebus saha...
# 23       Amazon matangkan rencana ekspansi di Indonesia
# 24    Daniel Zhang, penerus Jack Ma untuk masa depan...
# 25    Kecurangan promo yang berujung pemecatan karya...
# 26       Pedagang di media sosial juga bakal kena pajak
# 27                   Blibli.com buka kios di kantor pos
# 28              Magnet Go-Pay bagi para investor Go-Jek
# 29    Sebagian besar sektor menghijau, IHSG ditutup ...
# ...                                                 ...
# 1279        Eibar 3 - 0 Real Madrid - La Liga 2018/2019
# 1280  Valencia 3 - 0 Rayo Vallecano - La Liga 2018/2019
# 1281           Huesca 2 - 2 Levante - La Liga 2018/2019
# 1282  West Ham United 0 - 4 Manchester City - EPL 20...
# 1283            Watford 0 - 3 Liverpool - EPL 2018/2019
# 1284           Fulham 3 - 2 Southampton - EPL 2018/2019
# 1285         Everton 1 - 0 Cardiff City - EPL 2018/2019
# 1286  Manchester United 0 - 0 Crystal Palace - EPL 2...
# 1287  Brighton & Hove Albion 1 - 1 Leicester City - ...
# 1288  Inter Milan 3 - 0 Frosinone - Liga Serie A 201...
# 1289  Atletico Madrid 1 - 1 Barcelona - La Liga 2018...
# 1290  Spurs yang fantastis hadirkan kekalahan pertam...
# 1291        Persija ke puncak klasemen, Persib menyerah
# 1292    Indonesia pun gagal dalam AFF Beach Soccer 2018
# 1293         Lazio 1 - 1 Milan - Liga Serie A 2018/2019
# 1294       Napoli 0 - 0 Chievo - Liga Serie A 2018/2019
# 1295  Bologna 0 - 0 Fiorentina - Liga Serie A 2018/2019
# 1296     Empoli 3 - 2 Atalanta - Liga Serie A 2018/2019
# 1297      Parma 2 - 1 Sassuolo - Liga Serie A 2018/2019
# 1298     Athletic Club 1 - 1 Getafe - La Liga 2018/2019
# 1299          Espanyol 1 - 3 Girona - La Liga 2018/2019
# 1300  Sevilla 1 - 0 Real Valladolid - La Liga 2018/2019
# 1301      AFC Bournemouth 1 - 2 Arsenal - EPL 2018/2019
# 1302  Wolverhampton Wanderers 0 - 2 Huddersfield Tow...
# 1303         Fajar/Rian tuntaskan dahaga gelar di India
# 1304     Genoa 1 - 1 Sampdoria - Liga Serie A 2018/2019
# 1305    Villarreal 2 - 1 Real Betis - La Liga 2018/2019
# 1306  PSM kembali ke puncak klasemen, Persib resmi t...
# 1307              Hasil imbang yang pahit bagi AC Milan
# 1308  Seruan untuk Edy Rahmayadi di balik kegagalan ...
#
#                                                 Artikel    Jenis
# 0     Nilai tukar rupiah terhadap dolar Amerika Seri...  ekonomi
# 1     Perkembangan teknologi telah menyebabkan perub...  ekonomi
# 2     Media sosial kini bukan hanya menjadi alat unt...  ekonomi
# 3     Dalam menjalankan bisnis, menjalin relasi puny...  ekonomi
# 4     Merintis usaha memang bukan pekerjaan mudah. A...  ekonomi
# 5     Perdagangan di Bursa Efek Indonesia (BEI) ditu...  ekonomi
# 6     Indeks Harga Saham Gabungan (IHSG) terkoreksi ...  ekonomi
# 7     Proses ratifikasi tujuh perjanjian perdagangan...  ekonomi
# 8     Pemerintah mematangkan skema pembiayaan fasilt...  ekonomi
# 9     Anak muda zaman sekarang boleh jadi tidak asin...  ekonomi
# 10    Boeing Company kembali merilis buletin panduan...  ekonomi
# 11    Sejak masuk 2018, kondisi ekonomi global berge...  ekonomi
# 12    Pemilihan Umum (Pemilu) dan Pemilihan Presiden...  ekonomi
# 13    Pemerintah semakin serius menjaring minat inve...  ekonomi
# 14    Badan Koordinasi Penanaman Modal (BKPM) menyat...  ekonomi
# 15    Otoritas Jasa Keuangan (OJK) kembali mengungka...  ekonomi
# 16    Harga emas batangan milik PT Aneka Tambang Tbk...  ekonomi
# 17    Satuan Kerja Khusus Pelaksana Kegiatan Usaha M...  ekonomi
# 18    Bursa Efek Indonesia (BEI) berencana menurunka...  ekonomi
# 19    Masa depan layanan transportasi ride sharing t...  ekonomi
# 20    Rangkaian serangan bom yang menguncang Indones...  ekonomi
# 21    Menjual obligasi secara online tampaknya cocok...  ekonomi
# 22    Langkah PT Indonesia Asahan Aluminium (Inalum)...  ekonomi
# 23    Amazon, raksasa e-commerce asal Amerika Serika...  ekonomi
# 24    Perusahaan e-commerce raksasa, Alibaba Group, ...  ekonomi
# 25    Aksi oknum karyawan yang diduga melakukan kecu...  ekonomi
# 26    Pemerintah bakal mengenakan pajak buat para pe...  ekonomi
# 27    Blibli.com mengambil momentum awal tahun denga...  ekonomi
# 28    Pesona Go-Jek di mata investor belum redup. Me...  ekonomi
# 29    Indeks Harga Saham Gabungan (IHSG) terkoreksi ...  ekonomi
# ...                                                 ...      ...
# 1279  Eibar menjaga langkah untuk mendekatkan diri d...    sport
# 1280  Valencia menjaga langkah untuk mendekatkan dir...    sport
# 1281  Huesca dan Levante sama-sama gagal memetik poi...    sport
# 1282  Meski bermain di kandang sendiri, West Ham Uni...    sport
# 1283  Tuan rumah Watford dibuat terkejut oleh tim ta...    sport
# 1284  Fulham menjaga langkah untuk mendekatkan diri ...    sport
# 1285  Everton menjaga langkah untuk mendekatkan diri...    sport
# 1286  Manchester United dan Crystal Palace sama-sama...    sport
# 1287  Brighton & Hove Albion dan Leicester City sama...    sport
# 1288  Inter Milan menjaga langkah untuk mendekatkan ...    sport
# 1289  Atletico Madrid dan Barcelona sama-sama gagal ...    sport
# 1290  Kebahagiaan tengah hinggap di diri Mauricio Po...    sport
# 1291  Dua klub papan atas, Persija Jakarta dan Persi...    sport
# 1292  Bukan cuma timnas sepak bola yang gagal di lin...    sport
# 1293  Lazio dan Milan sama-sama gagal memetik poin m...    sport
# 1294  Napoli dan Chievo sama-sama gagal memetik poin...    sport
# 1295  Bologna dan Fiorentina sama-sama gagal memetik...    sport
# 1296  Empoli berhasil menjauhi zona degradasi setela...    sport
# 1297  Parma menjaga langkah untuk mendekatkan diri d...    sport
# 1298  Athletic Club dan Getafe sama-sama gagal memet...    sport
# 1299  Tuan rumah Espanyol dibuat terkejut oleh tim t...    sport
# 1300  Sevilla menjaga posisi puncak di klasemen La L...    sport
# 1301  Tuan rumah AFC Bournemouth dibuat terkejut ole...    sport
# 1302  Tuan rumah Wolverhampton Wanderers dibuat terk...    sport
# 1303  Ganda putra Indonesia, Fajar Alfian/Muhammad R...    sport
# 1304  Genoa dan Sampdoria sama-sama gagal memetik po...    sport
# 1305  Villarreal menjaga langkah untuk mendekatkan d...    sport
# 1306  Persija Jakarta harus rela kembali ke peringka...    sport
# 1307  "Hasil imbang yang pahit." Begitu laman resmi ...    sport
# 1308  Timnas Indonesia mengakhiri babak grup Piala A...    sport
#
# [1309 rows x 3 columns]

# %%
label = dataset.iloc[:,2]
feature = dataset.iloc[:,0]

# %%
#fungsi2 untuk normalisasi dataset
character = ['z','y','x','w','v','u','t','s','r','q','p','o','n','m','l','k','j','i','h','g','f','e','d','c','b','a',
             ',','.',';',':','-','...','?','!','(',')','[',']','{','}','<','>','"','/','\'','#','-','@']
def repeatcharNormalize(text):
    for i in range(len(character)):
        charac_long = 5
        while charac_long>=2:
            char=character[i]*charac_long
            text=text.replace(char,character[i])
            charac_long-=1
        return text

def spellNormalize(text):
    spellCheck = []
    for i in text:
        if i not in character:
            j=sc.correction(i)
            spellCheck.append(j)
        else:
            spellCheck.append(i)
        return spellCheck  
    
def tokenize_text(text):
    tokens=nltk.word_tokenize(text)
    tokens=[token.strip() for token in tokens]
    return tokens

def expand_contractions(text, contraction_mapping):
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),
                                    flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                            if contraction_mapping.get(match)\
                            else contraction_mapping.get(match.lower())
        expanded_contraction = first_char + expanded_contraction[1:]
        return expanded_contraction
    
    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'","", expanded_text)
    return expanded_text

def stemmer_text(text):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    text = stemmer.stem(text)
    return text

# def lemmatize_text(text):
#     pos_tagged_text = pos_tag_text(text)
#     lemmatized_tokens = [wnl.lemmatize(word, pos_tag) if pos_tag
#                        else word for word,
#                        pos_tag in pos_tagged_text]
#     lemmatize_text=' '.join(lemmatized_tokens)
#     return lemmatize_text

# %%
def remove_special_characters(text):
    tokens = tokenize_text(text)
    pattern = re.compile('[{}]'.format(re.escape(string.punctuation)))
    filtered_tokens = filter(None, [pattern.sub('',token) for token in tokens])
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

factory = StopWordRemoverFactory()
stopword_list = factory.get_stop_words()

def remove_stopwords(text):
    tokens = tokenize_text(text)
    filtered_tokens = [token for token in tokens if token not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

def normalize_corpus(corpus, tokenize=False):
    normalized_corpus = []
    for text in corpus:
        text = expand_contractions(text, CONTRACTION_MAP)
        text = stemmer_text(text)
        text = remove_special_characters(text)
        text = repeatcharNormalize(text)
        text = remove_stopwords(text)
        
        normalized_corpus.append(text)
        if tokenize:
            text = tokenize_text(text)
            text = spellNormalize(text)
            normalized_corpus.append(text)
    return normalized_corpus

# %%
#Fungsi untuk mengekstraksi feature menggunakan TF-IDF Model

def tfidf_transformer(bow_matrix):
    transformer = TfidfTransformer(norm='l2',
                                  smooth_idf=True,
                                  use_idf=True)
    tfidf_matrix = transformer.fit_transform(bow_matrix)
    return transformer, tfidf_matrix

def tfidf_extractor(corpus, ngram_range=(1,1)):
    vectorizer = TfidfVectorizer(min_df=1,
                                norm='l2',
                                smooth_idf=True,
                                use_idf=True,
                                ngram_range=ngram_range)
    features = vectorizer.fit_transform(corpus)
    return vectorizer, features

# %%
#training dataset
def prepare_datasets(corpus, labels, test_data_proportion=0.3):
    train_X, test_X, train_Y, test_Y = train_test_split(corpus, labels,
                                                       test_size=0.33, random_state=42)
    return train_X, test_X, train_Y, test_Y

def remove_empty_docs(corpus, labels):
    filtered_corpus = []
    filtered_labels = []
    for doc, label in zip(corpus, labels):
        if doc.strip():
            filtered_corpus.append(doc)
            filtered_labels.append(label)
    return filtered_corpus, filtered_labels

train_corpus, test_corpus, train_labels, test_labels = prepare_datasets(feature,
                                                                       label,
                                                                       test_data_proportion=0.3)
#memanggil fungsi normalisasi dataset yang telah ditraining
norm_train_corpus = normalize_corpus(train_corpus)
norm_test_corpus = normalize_corpus(test_corpus)
''.strip()
# Out:
# ''

# %%
norm_train_corpus
# Out:
# ['pssi tahan luis milla',
#  'lidi knkt kabar baru insiden lion air jt610',
#  'fakta putar hiu raksasa megalodon',
#  'sanksi berat persib sop tampak wujud',
#  'tiga nyanyi bintang film baru ernest prakasa',
#  'ac mil butuh waktu',
#  'beda dana desa lurah',
#  'kotak hitam temu satu korban makam',
#  '10 sektor seret lemah ihsg',
#  'mahal hasil imbang mil laju 7 tim mapan',
#  '9 vendor ponsel bakal unjuk gigi ifa 2018',
#  'hoaks tengah bencana polisi tangkap orang',
#  'mk tolak gugat ambang batas caprescawapres',
#  'tarif listrik tak naik subsidi makin tinggi',
#  'ungkap kalimat paling seksi pasang',
#  'alas apple buang 3d touch iphone datang',
#  'orang rupawan kurang untung cinta',
#  'keju tua temu makam mesir',
#  'riset ungkap cara lebih sadar diri',
#  '47 ilmuwan diaspora ikut simposium cendekia kelas dunia 2018',
#  'parma 0 2 lazio liga serie a 2018 2019',
#  'asal warna berlian biru hasil pecah',
#  'kunto aji sorot isu sehat mental lewat album mantra mantra',
#  'usaha masalah banyak alam',
#  'ketua golkar jabar usul standar bantu rutilahu rp 35 juta',
#  'cadang devisa tetap aman meski nilai turun',
#  'karakter pasang anggap tarik psikopat',
#  'risiko tingkat utang luar negeri kendali',
#  'ikan tumbuh dewasa 14 hari',
#  'sampdoria 0 0 sassuolo liga serie a 2018 2019',
#  'investor bisnis tak perlu khawatir milu 2019',
#  'kenal enam masalah kulit cara atas',
#  'jawab atas runtuh adab indus',
#  'kalah alaves madrid tengah puruk',
#  'pagi kupang goyang 3 kali gempa',
#  'juang pilih karier orang tua',
#  'yahoo messenger berlian hingga ponsel mudah rusak',
#  'kenal enam masalah kulit cara atas',
#  'perang argumen vaksin tak',
#  'masa darurat habis evakuasi henti',
#  'siapa henti laju manchester city',
#  '3 zona festival tonton gbk',
#  'polemik dana lurah modus politik sejahtera',
#  'hasil rocket lab awal saing startup antariksa',
#  'solusi dingin ruang hemat listrik',
#  'psm persija gagal manfaat kalah persib',
#  'rekor bawa solar kursi latih tetap real madrid',
#  'kenal suku sentinel manah misionaris as',
#  'klaim baru duga lokasi atlantis',
#  'serba mini pesta tutup',
#  'megawati ungkap awal mula akrab maruf amin',
#  'ginting final the minions ganjal',
#  'huddersfield town 0 1 liverpool epl 2018 2019',
#  'xiaomi indonesia bungkam atas pocophone',
#  'kisah heroik anthonius prosedur terbang bandara palu',
#  'kiat maksimal facebook bisnis',
#  '8 sektor perkasa lambung ihsg',
#  'hari baik ganda putra changzhou',
#  'orkestra messi lumpuh tottenham',
#  'fujifilm instax square sq20 jiwa muda',
#  'bantu logistik kaltim tolak palu',
#  'bencana informasi kitar jatuh lion air',
#  'jatah fee proyek jadi modus banyak korupsi kepala daerah',
#  'persija puncak klasemen persib serah',
#  'kevin marcus kuasa final',
#  'partai beban biaya saksi perintah',
#  'anies ungkap alas ganjilgenap panjang',
#  'blibli com buka kios kantor pos',
#  '5 hambat karier',
#  'satu medali emas bawa pulang',
#  'girona 0 0 leganes la liga 2018 2019',
#  'sri mulyani rasa khianat',
#  '3 beda utama orang sibuk orang produktif',
#  'biasa kandidat kualifikasi tinggi cari kerja',
#  '3 abk wni culik lepas pantai kongo',
#  '5 cari kerja tolak hrd',
#  'indeks modal manusia indonesia bawah vietnam filipina',
#  'asa indonesia tunggal putra',
#  'jangan biar harimau punah',
#  '5 alas tepat undur diri',
#  'indra sjafri optimistis hadap laga grup a',
#  'curang promo ujung pecat karyawan tokopedia',
#  'manchester city 2 0 brighton hove albion epl 2018 2019',
#  'ekonomi asia cukup solid meski tak sepenuh aman',
#  'juventus manchester united rusak hari bagus ronaldo',
#  'the predator tak laris pimpin box office',
#  'ekonomi 2015 indah harap',
#  'lapis ozon sembuh 2060',
#  'kalah mil kecewa gattuso',
#  'city chelsea liverpool ulang sejarah empat dekade',
#  'cerai turun keluarga',
#  'tarif mrt jakarta versi jokowi tak lebih rp10 000',
#  'anggar pangkas target tumbuh tambah',
#  'aku zumi zola seret anggota dprd jambi',
#  'tumbuh ekonomi balik prestasi atlet',
#  '7 kabar putar gaya hidup ujung 2017',
#  'asean sama pandang soal konsep indopasifik',
#  'busa limbah cari kali bekas',
#  'siap diri jadi usaha sukses',
#  '4 alas tak duga usaha tolak',
#  'tabung goreng antikolesterol inovasi guru sma',
#  'kader tak haluan pimpin partai',
#  'matahari buat tiongkok lebih panas sang surya',
#  'badai palembang porakporandakan stasiun lrt jakabaring',
#  'cara tahun ekonomi indonesia baik',
#  'kiat rebranding bangkit bisnis lesu',
#  'xiaomi luncur ponsel anyar bas android one',
#  'athletic club 0 0 valencia la liga 2018 2019',
#  'vina rebut perunggu angkat besi argentina',
#  'aries susanti juara turnamen internasional',
#  'ketua golkar jabar usul standar bantu rutilahu rp 35 juta',
#  'baru film mata batin 2',
#  'jadi komuter lebih bahagia',
#  'indonesia u19 selang tuju piala dunia u20',
#  'fajar rian rontok empat wakil ikut keok',
#  'rapat baik turut sains',
#  'misteri arah naik tunda harga premium',
#  'lampu kuning timnas u19 empat final',
#  'cuat duga atur skor liga 2',
#  'ciri selingkuh hati',
#  'zumi zola tuntut 8 tahun penjara',
#  'psm puncak klasemen persib resmi sisih',
#  'jawab tanya lemah besar',
#  'perintah swasta sepakat biaya proyek nonapbn',
#  'umum kerja milenial bayar upah minim',
#  'kevin marcus tuju surga tujuh',
#  'rayo vallecano 2 3 barcelona la liga 2018 2019',
#  'tahun 536 nominasi bagai era buruk manusia',
#  'bal punya 11 desa wisata baru',
#  'perempuan lebih baik hati laki',
#  'kapal sar laksamana evakuasi 2 jenazah air teluk palu',
#  'taufik kurniawan kursi panas pimpin dpr',
#  'satelit merah putih siap operasi penuh bulan depan',
#  'jepang punya semua jawab atas tantang indonesia',
#  'putraputri u17 pb djarum lang final',
#  'brighton hove albion 1 0 west ham united epl 2018 2019',
#  'sulit temu karier impi',
#  'kasus taufik kurniawan potensi seret kolega dpr',
#  'newcastle united 0 2 leicester city epl 2018 2019',
#  'audit bpk bukan cari salah',
#  'massa diam literasi digital panggung teater',
#  'kendali turnover karyawan tinggi',
#  'pirates of the carribean baru johnny depp',
#  'film keluarga cemara kemas milenial',
#  'tiongkok rehabilitasi candu narkoba vr',
#  'burung gagak sanggama bangkai sama',
#  'wayang dakwa ganda bupati purbalingga',
#  'brighton hove albion 1 1 leicester city epl 2018 2019',
#  'burnley 1 1 huddersfield town epl 2018 2019',
#  'film something in between madu aktor beda generasi',
#  'greysia apriyani marcus kevin jaga asa indonesia',
#  'cardiff city 4 2 fulham epl 2018 2019',
#  'kata erix soekamti soal tegur jerinx sid via vallen',
#  '5 alas cari kerja baru',
#  'leicester city 1 2 everton epl 2018 2019',
#  'peluang borong piala ffi 2018',
#  'pesona rhoma irama industri dangdut',
#  'marquez kunci gelar juara dunia motegi',
#  '5 sikap batal promosi',
#  '3 bahasa tubuh wawancara antisipasi',
#  'situasi negeri bangkit ekonomi',
#  'hadap gejolak ekonomi global',
#  'kampanye reklamasi u16 hingga tewas jakmania',
#  'akhir jalan yahoo bagai usaha mandiri',
#  'alas orang baik benci kantor',
#  'kuda laut babi jepang ukur beras',
#  'kenal kubah lava muncul gunung rapi',
#  'film a man called ahok raih 1 juta tonton ahok ucap terima kasih artikel tayang kompas com judul film a man called ahok raih 1 juta tonton ahok ucap terima kasih',
#  'wejang jack ma usaha muda',
#  'daftar ponsel pintar paling sering rusak',
#  'jangan lambat reforma agraria polemik',
#  'anak pangeran william dongkrak ekonomi hingga rp 19 triliun',
#  'desa microsoft as kait regulasi kenal wajah',
#  'ekonomi tahun sulit tumbuh 5 4 persen',
#  'gajah klaim kebal hadap kanker',
#  'spesies bunga bangkai dibudidayakan bengkulu',
#  'pindah kerja tak selalu jadi putus baik',
#  'teliti ubah golong darah jadi universal',
#  'mindfulness buat orang lebih empat',
#  'tiga film baru tak mampu kalah venom',
#  'google rilis ai berantas konten pornografi anak',
#  'ubah iklim rip current hingga samsung galaxy a9',
#  'indonesia tambah ekspor tiongkok lewat jack ma',
#  '4 cara ajar cinta kerja',
#  'jojo ginting tarung babak',
#  'polemik frasa politikus sontoloyo jokowi',
#  'god bless siap gelar konser hari untun',
#  'lokasi likuefaksi jadi monumen bencana',
#  'ekonomi gerak tengah macet jalan',
#  'balik agenda latih tanding level timnas indonesia',
#  'halloween perkasa baris film laris',
#  'west ham united 0 1 tottenham hotspur epl 2018 2019',
#  'bologna 2 2 torino liga serie a 2018 2019',
#  'wolverhampton wanderers 2 3 tottenham hotspur epl 2018 2019',
#  'dominasi kevin marcus atas ganda putra tiongkok',
#  'menang atas psg liverpool mampu daki semua gunung',
#  'sedikit psm butuh nilai 65 juara',
#  'tanda hubung rusak baik',
#  'celta de vigo 0 1 deportivo alaves la liga 2018 2019',
#  'hitung peluang indonesia lolos semifinal',
#  'cari untung lewat obligasi negara deposito bank',
#  'fosil pterodactyl parker solar probe hingga manusia kuno turki',
#  'kerja keras timnas u19 kalah taiwan',
#  'kemenhub inspeksi ulang boeing 737 max 8 milik lion garuda',
#  'huesca 0 1 rayo vallecano la liga 2018 2019',
#  'ironi negeri cincin api minim sadar asuransi',
#  'luna x prime hadir fitur kelas atas harga tengah',
#  'kerja mrt fase ii ancol',
#  'bunuh kaisar romawi pengaruh kering',
#  'levante 1 3 real sociedad la liga 2018 2019',
#  'arsenal 1 1 liverpool epl 2018 2019',
#  'jbl rilis headset tahan air',
#  'spal 2 2 cagliari liga serie a 2018 2019',
#  'sering dibully megawati pamer hasil survei elektabilitas pdip',
#  'spal 0 3 frosinone liga serie a 2018 2019',
#  'juara hong kong kevin marcus kalung rekor',
#  'peran krusial bal united ancam degradasi 12 tim',
#  'kiat damping anak gawai',
#  'residivis kelompok jarah palu',
#  'wolverhampton wanderers 0 2 huddersfield town epl 2018 2019',
#  'untung rugi ratifikasi tujuh janji dagang asean',
#  'kenal 4 manfaat biji labu kuning sehat',
#  'the 90s festival hadir nuansa tiga dekade lampau',
#  'marquez tang tarung seru versus dovizioso aragon',
#  'real madrid 0 0 atletico madrid la liga 2018 2019',
#  'penting resign cara hormat',
#  'cerita acha septriasa soal casting fantastic beasts 2',
#  '5 pola pikir lama atas tinggal',
#  'berry hardianto lengkap dominasi ganda putra indonesia',
#  'jadwal tayang wonder woman 1984 undur',
#  'menang persija bayang ingat ricuh suporter',
#  'atur uang mindfulness',
#  'hutan gunung ciremai bakar kali lebih luas',
#  'nostalgia film indonesia korea indonesia film festival 2018',
#  'pesan hary tanoe caleg perindo menang partisipasi buat bijak',
#  'jelang lahir sang buah hati gya sadiqah alami sindrom pregnancy brain',
#  'jadwal cuci tepat jadi pakai lebih awet',
#  'resign butuh cuti',
#  'ronald annisa tunduk unggul lima tontowi della kalah telak',
#  'nikon coba kejar sony lewat z6 z7',
#  'komisi ii minta kpud malut tindaklanjuti rekomendasi bawaslu',
#  'temu baru mumi kucing kumbang tinggal mesir kuno',
#  'chievo 1 5 atalanta liga serie a 2018 2019',
#  'utama rumah bakar',
#  'antusiasme warna kudus relay marathon 2018',
#  'cacing puluh ribu tahun hidup',
#  'klub dominasi prestasi tim',
#  'jual pc dunia turun drastis',
#  'real madrid 2 0 real valladolid la liga 2018 2019',
#  'gempa 6 0 sr guncang situbondo 3 warga sumenep tewas',
#  'upaya jadi dana saksi partai bagai tanggung negara',
#  'pesan diri alibaba bisnis langgeng',
#  'basuki hadimuljono disiplin ikut tata ruang',
#  'lazio 4 1 spal liga serie a 2018 2019',
#  'cara hadap gagal turut ilmuwan',
#  'tingkat adopsi ios 11 tembus 85 persen',
#  'hewan rasa bahagia sedih',
#  'agung yulianto siap kembang chemistry anies',
#  'duduk asia lebih papar polusi udara ketimbang duduk barat',
#  '2 bocah tewas renang kali banjir kanal palmerah',
#  'tak kunjung panggil wawancara',
#  'jokowi harap target atlet peleset atas',
#  'kecewa madrid tahan imbang bilbao',
#  'rupiah rawan gejolak',
#  'menang perdana djanur sama baya',
#  'mil 0 2 juventus liga serie a 2018 2019',
#  'burung suka kuping selamat diri',
#  'komodo indonesia',
#  'halloween amuk tangga box office',
#  '4 ucap sering disalahartikan lamar',
#  'pilih karier tak dukung orang tua',
#  'kaya trump duga hasil gelap pajak',
#  'manchester united 2 1 everton epl 2018 2019',
#  'emergency button aplikasi tombol darurat tulungagung',
#  'villarreal 1 1 levante la liga 2018 2019',
#  'bantu asing fokus rehabilitasi',
#  'psi korupsi jamaah anggota dprd coreng wajah kota malang',
#  'kiat rintis bisnis filosofi kopi',
#  'bulu tangkis muda indonesia ulang capai 6 tahun lalu',
#  '2 gol ronaldo antar juventus ulang sejarah',
#  'efek buruk tiru gaya rambut ariana grande tiap hari',
#  'huawei pamer cip kirin 980 ukur kuku jari',
#  'chelsea kejar rekor mu banjir soal',
#  'utang perintah naik apa',
#  'parma 0 0 frosinone liga serie a 2018 2019',
#  'sejarah indonesia harap jadi katalisator dunia',
#  'kiat nyaman pergi kereta api',
#  'chievo 0 1 torino liga serie a 2018 2019',
#  'eibar 3 0 real madrid la liga 2018 2019',
#  'rekomendasi baru soal gawai anak rilis',
#  'televisi android jangkau coocaa',
#  'ekstrak teh hijau tingkat risiko rusak hati',
#  'upacara buka bakal sarat pesan manusia',
#  'impresi sabak samsung galaxy tab s4',
#  'cardiff city 2 1 brighton hove albion epl 2018 2019',
#  'huddersfield town 0 2 tottenham hotspur epl 2018 2019',
#  'polusi udara tumpul otak',
#  'dominasi lari kenya electric jakarta marathon 2018',
#  'magnet gopay investor gojek',
#  'jokowi tuduh antek asing mana',
#  'girona 2 1 rayo vallecano la liga 2018 2019',
#  'bpk temu masalah rp11 5 triliun semester i',
#  '5 mitos kelola waktu ancam produktivitas',
#  'crystal palace 2 2 arsenal epl 2018 2019',
#  'penting suka kerja',
#  'politik identitas prediksi tak laku milu',
#  'deportivo alaves 2 1 villarreal la liga 2018 2019',
#  'polisi ungkap identitas laku tembak massal bar california',
#  'tiongkok tajam catat indonesia sesuai target',
#  'kapan momen tepat beli gawai',
#  'whatsapp mulai cari uang',
#  'tujuh sektor ekonomi paling rugi asap',
#  'bts pecah rekor youtube',
#  'setya novanto titip surat tanah kpk',
#  'tembak 11 warga 14 paket bom gempar as',
#  'chelsea 2 2 manchester united epl 2018 2019',
#  '31 juta warga rekam ektp masuk dpt',
#  'blunder rapuh balik kalah tipis timnas u19',
#  'persib pupuk asa tujuh laga',
#  'chievo 0 2 sassuolo liga serie a 2018 2019',
#  'terampil penting ajar jadi efektif',
#  '4 tipe wawancara kerja',
#  'raksasa era triassic bukan dinosaurus',
#  'brighton hove albion 1 0 wolverhampton wanderers epl 2018 2019',
#  'roda ekonomi putus akibat gempa',
#  'tingkat aman usai tindak vandalisme kereta bandara',
#  'barcelona lolos inter punya kans besar',
#  'torino 1 2 parma liga serie a 2018 2019',
#  'darurat sawah perintah bakal beli lahan',
#  'buat rumah lebih aman si kecil',
#  'pesawat airbus bentuk paus putih sukses udara',
#  'gp valencia bukan sekadar tutup musim',
#  'gempa besar picu gempa bahan bumi',
#  'satelit merah putih gempa besar hingga manusia kerdil flores',
#  'daniel zhang terus jack ma masa depan alibaba',
#  'soal mungkin nikah sule gantung emak',
#  'bahagia awet libur usai',
#  'sempat akhir rehan fadia turnamen junior',
#  'data satelit ungkap misteri benua kuno bawah antartika',
#  'main muda indonesia mulai unjuk gigi',
#  'the grinch duduk singgasana film laris',
#  'spesifikasi lanjut pocophone f1 xiaomi kian jelas',
#  'juventus ronaldo diesel',
#  'onar kasus ratna sarumpaet',
#  'mobil pelat merah duta rekam etilang',
#  'makhluk daun nyata hewan purba',
#  '31 tahun inggris akhir menang spanyol',
#  'laku bila atas kurang kompeten',
#  'wolverhampton wanderers 0 2 watford epl 2018 2019',
#  'diri microsoft ramai saing tuju luar angkasa',
#  'hasil jomplang ganda putra ganda putri',
#  '4 tanda wawancara gagal cara atas',
#  'sassuolo 2 2 bologna liga serie a 2018 2019',
#  'gaet investor kecil bursa turun satu lot saham',
#  'hasil kawin silang paus lumbalumba lihat hawaii',
#  'bos sebal hingga masalah cerna',
#  'udinese 1 0 roma liga serie a 2018 2019',
#  'warner bros dekat margot robbie peran barbie',
#  'arab saudi eksekusi mati tuty pemberitahuan indonesia',
#  'bank dunia revisi proyeksi tumbuh ekonomi global',
#  'bhayangkara fc jaga harap',
#  'sassuolo 1 1 lazio liga serie a 2018 2019',
#  'fakta tarik lomba lari ekiden',
#  'indonesia tari 2018 guncang mal grand indonesia',
#  'perintah bentuk satgas rehabilitasi',
#  'man city puruk tim unggul menang',
#  'frosinone 1 1 fiorentina liga serie a 2018 2019',
#  'digitalisasi ekonomi desa',
#  'wali kota pasuruan jajar kepala daerah jatim jerat korupsi',
#  '3 dara 2 sentil biasa suami remeh istri',
#  'kisruh sampah bantargebang usai',
#  'west ham united 0 4 manchester city epl 2018 2019',
#  'tip jaga sehat mental tempat kerja',
#  'presiden jokowi anugerah 6 orang gelar pahlawan nasional',
#  'kental nuansa aadc milly mamet',
#  'polemik kampanye sekolah pesantren',
#  'pulih ekonomi kredit daerah bencana longgar',
#  'levante 2 0 leganes la liga 2018 2019',
#  'cara manusia kuno turki tanggap ubah iklim',
#  '5 wakil indonesia jaga asa jadi juara',
#  '10 heboh anies media tahun',
#  'faktor internal tahan rupiah jatuh lebih',
#  'inter mil 3 0 frosinone liga serie a 2018 2019',
#  'balikpapan jadi pusat transit pesawat asing muat bantu',
#  'hidup galaksi sempat mati',
#  'messi lelah cetak tiga gol',
#  'logic board iphone 8 masalah apple siap baik gratis',
#  'facebook penting ekonomi dunia',
#  'roma 4 1 sampdoria liga serie a 2018 2019',
#  'film horor indonesia gagal populer bumbu mesum',
#  'beberapa burung tak ikut kontes kicau',
#  'suhu dingin indonesia biasa jadi juniagustus',
#  'beda hitung surplus beras bps menteri tani',
#  'buru poin turnamen tutup tahun',
#  'rusia niat bangkit mammoth',
#  'raja jokowi jadi presiden',
#  'bawa bendera duga hti tahan polisi',
#  'coldplay siap bikin album baru',
#  'rumus bisnis langgeng',
#  'jennie blackpink cetak rekor lagu solo',
#  'kevin marcus lolos krisis',
#  'ingat dini tiba beberapa detik gempa',
#  'jejak manusia hampir 90 persen laut bumi',
#  'halloween turut kritikus',
#  'bintang game of thrones ramai indonesia comic con 2018',
#  'orang kaya baru jadi komedi pertama raline shah',
#  'cara investasi tetap sesuai tuju',
#  'romano fenati tinggal dunia balap motor pecat',
#  'perlu cari muka atas',
#  'tuntut 8 tahun penjara cabut hak politik zumi zola',
#  '11 indikator krisis ekonomi',
#  'canda tawa jaga api asmara tetap bara',
#  'napoli 1 1 roma liga serie a 2018 2019',
#  'burung julang sulawesi tani hutan ancam punah',
#  'kirim kantong jenazah capai 73 jumlah anggota sar tambah',
#  'satu kota inggris nobat bagai tempat kerja baik',
#  'italia turun kasta polandia',
#  'hidup seks harmonis tak jamin setia',
#  'kenal bangkit listrik panas bumi ulumbu ntt',
#  'musibah banjir bandang madrasah mandailing natal',
#  'mendagri minta kepala daerah sambut atlet juang asi games',
#  'chievo 2 2 bologna liga serie a 2018 2019',
#  'billyeddy sindoro kakakadik pusar kasus korupsi',
#  'ganjilgenap jalan jakarta laku hingga akhir 2018',
#  'tahu usai babak grup',
#  'tak kunjung promosi kantor',
#  'huesca 2 2 levante la liga 2018 2019',
#  'madrid pecat lopetegui conte labuh',
#  'fajar rian tuntas dahaga gelar india',
#  'babak baru thierry henry wenger guardiola',
#  'rasa sensasi jadi wiro sableng',
#  'arsenal 2 0 watford epl 2018 2019',
#  'barcelona 3 4 real betis la liga 2018 2019',
#  'ojk ungkap 20 usaha investasi bodong',
#  'jalan putus 10 nagari isolasi',
#  'huesca 1 1 girona la liga 2018 2019',
#  'kisah cinta perempuan refleksi masa lalu sang ibu',
#  'bupati cirebon harga jabat ala menu restoran',
#  'genoa 1 2 napoli liga serie a 2018 2019',
#  'bagaimana media sosial ubah pola asuh',
#  'perempuan lebih rentan jadi candu ganja',
#  'inter mil 1 0 mil liga serie a 2018 2019',
#  'genoa 2 2 udinese liga serie a 2018 2019',
#  '3 sifat buat manfaat tempat kerja',
#  'strategi capai merdeka uang',
#  'sekolah skotlandia bakal ajar sejarah budaya lgbt',
#  'santun hingga rp25 juta ahli waris korban gempa',
#  'suap pltu riau1 eni saragih aju jc kpk',
#  'tiongkok sukses prediksi gempa 43 tahun lalu',
#  'raih dana rp58 triliun inalum siap tebus saham freeport',
#  'maut bayang laju persib',
#  'upaya konservasi biota laut apartemen ikan',
#  'kisah nyata balik seram valak',
#  'atletico madrid 3 2 athletic club la liga 2018 2019',
#  'selukbeluk sbmptn 2019 cara baru masuk universitas',
#  'teori baru asal muasal air bumi',
#  'roma 3 1 lazio liga serie a 2018 2019',
#  'rasa malas jadi faktor selamat punah',
#  'uji hubung lancong',
#  'everton 2 0 crystal palace epl 2018 2019',
#  'delapan wakil indonesia kejar tiket empat final',
#  'first man turut kritikus',
#  'drive laju vokalis baru',
#  'turun saham tiongkok pengaruh ekonomi dunia',
#  'belanda kalah prancis kirim jerman turun kasta',
#  'kerja ekspor surat utang topang tingkat devisa',
#  'paus bunuh punya pribadi persis manusia simpanse',
#  'persib kandas papan atas panas',
#  'imbal rp200 juta buat lapor korupsi',
#  'siap pasuk revolusi industri 4 0',
#  'temu planet panas hampir sama suhu matahari',
#  'sendiri beda sepi',
#  'jepang antiklimaks arab tantang korea partai final',
#  'kembang soko guru ekonomi',
#  'benar burung indah tak pandai kicau',
#  'hasil imbang pahit ac mil',
#  'kenal synaesthesia orang dengar warna',
#  'turki papar kronologi bunuh khashoggi',
#  'temu ramu awet mumi mesir kuno',
#  'banjir terjang jumlah daerah sumatra',
#  'fulham 0 3 afc bournemouth epl 2018 2019',
#  'cabor catur boyong 11 emas harap masuk paralimpiade',
#  'crazy rich asians raja box office',
#  'pandu wawancara kerja usai kena phk',
#  'manchester city 5 0 burnley epl 2018 2019',
#  'plastik turut peran panas global',
#  'persib makin jauh puncak klasemen',
#  'polisi perang lawan hoaks 13 warganet ciduk',
#  'arab saudi raih tiga gelar indonesia puji',
#  'napi kabur pascagempa janji',
#  'manusia purba hidup tiongkok 2 1 juta tahun lalu',
#  'apa diabetes anak',
#  'koordinasi buruk perintah daerah sulteng kritik',
#  'gempa magnitudo 4 6 jadi mamasa sulbar',
#  'jerat kpk buat lucas kandas',
#  'terlalu sering googling tingkat risiko demensia',
#  'teknologi paksa usaha adaptasi lebih cepat',
#  '4 kunci tahan karyawan baik',
#  'liga primer pilih susanna dinnage jadi ceo baru',
#  'real sociedad 0 0 sevilla la liga 2018 2019',
#  'bahaya makan daging anjing',
#  'waktu makan anak pengaruh tumbuh kembang optimal',
#  'huddersfield town 1 0 fulham epl 2018 2019',
#  'mahasiswa indonesia buat tinta pendar bakteri',
#  'antre bbm terus langsung meski stok bbm cukup',
#  'astronaut sendawa ruang angkasa',
#  'lombok kebut rehabilitasi gerak ekonomi',
#  'manfaat satelit daerah rawan bencana',
#  'kenal tipe pribadi abcd',
#  'wajah jenggot perlu awat kulit',
#  'kesal rossi tangis gemar cilik',
#  'tabrak sepeda daftar celaka bus transjakarta makin panjang',
#  'ateng iskak hidup ateng',
#  'hoaks bayang milu',
#  'indonesia maju empat final rekor mulus',
#  'anthonius sang pahlawan menara bandara',
#  'tunduk ps tira psm akhir paceklik menang',
#  'belanda akhir 16 tahun dominasi jerman',
#  'hujan batal ingat sumpah pemuda bogor',
#  'kisah cinta perempuan refleksi masa lalu sang ibu',
#  'alkohol tajam ingat',
#  'diam tahu gaji bos picu semangat kerja',
#  'siswi asal diri cipta tisu basah organik',
#  'dominasi kampus as nobel ekonomi',
#  'anthony ginting lelah tekad tahan gelar',
#  'villarreal 2 1 real betis la liga 2018 2019',
#  'rugi tak riset wawancara kerja',
#  'penting sisih waktu luang tetap waras',
#  'celta de vigo 4 0 eibar la liga 2018 2019',
#  'laga dramatis istora ginting hadap shi yuqi',
#  'prinsip dasar rintis bisnis',
#  'banyak caleg tahana tak lapor harta kaya',
#  'retorika prabowo bangun politik identitas',
#  'paket bijak ekonomi vi target daerah pinggir',
#  'pb djarum pb jaya raya menang telak',
#  'kuskus mata biru ternate kian langka',
#  'nasa sebut air bulan',
#  'ungkap adegan tambah film wiro sableng',
#  'cara emas makan bau sengat',
#  'jelas rasa panik candu internet tak wifi',
#  'guns n roses keliling dunia dulang laba',
#  'malaysia siap hapus hukum mati',
#  'manchester united 3 2 newcastle united epl 2018 2019',
#  'west ham united 3 1 manchester united epl 2018 2019',
#  'del toro film kisah pinokio',
#  'mourinho tetap tenang meski hujan kritik',
#  'inter mil 5 0 genoa liga serie a 2018 2019',
#  'manchester city 6 1 southampton epl 2018 2019',
#  'southampton 1 1 watford epl 2018 2019',
#  'sontoloyo ala jokowi data miskin prabowo banser',
#  'jokowi kritik perang dagang lewat game of thrones',
#  'nilai merah jokowi tuntas kasus langgar ham',
#  'proyeksi ekonomi 2016 bayang tiongkok',
#  'warna tua vaksin hiv hingga anjing kecil dunia',
#  'fotografi ponsel ganggu ingat',
#  'naik harga bbm jadi solusi selamat cadang devisa',
#  'manfaat kopi lebih optimal nikmat panas',
#  'penting sisih waktu luang tetap waras',
#  'taktik tak jalan indonesia imbang vietnam',
#  'minions hadap daddies hong kong coliseum',
#  'afc bournemouth 1 2 manchester united epl 2018 2019',
#  'iespl tokopedia gelar kompetisi esports hadiah rp1 9 miliar',
#  'lawan rasa betah kantor baru',
#  'ikut grebek rumah angel lelga saksi bu rt status nikah vicky prasetyo',
#  'mungkin jokowimaruf capai target suara 70 persen',
#  'jojo singkir anthony lolos babak',
#  '523 tim mahasiswa laga utu awards 2018',
#  'kroasia untung kalah spanyol',
#  'cardiff city 1 2 burnley epl 2018 2019',
#  'toyota suntik grab uang rp14 triliun',
#  'polisi main tahan bikin sesak rutan',
#  'urgensi benah fundamental ekonomi',
#  'terlalu sering pindah kerja pengaruh karier',
#  '5 tanda hasil jadi pimpin',
#  'hilang kuman knkt sih barang pribadi korban lion air',
#  'berapa sering perempuan cukur rambut ketiak',
#  'nokia x6 ubah nama jadi nokia 6 1 plus pasar global',
#  'redmi 6a ponsel murah tarik',
#  'suka duka kerja kreatif agency',
#  'perempuan makin pintar makin sulit cari pasang',
#  '4 langkah kelola gaji target meni',
#  'jokowi temu jack ma bangun indonesia',
#  'batik asi games 2018',
#  'jupiter punya lusin bulan baru',
#  'diskusi tata kelola musik indonesia archipelago festival',
#  'peran ekonomi kreatif hadap tumbuh ekonomi nasional',
#  'barcelona 5 1 real madrid la liga 2018 2019',
#  'roma 0 2 spal liga serie a 2018 2019',
#  'kenal diet gaps derita autisme',
#  'selamat tinggal yahoo messenger',
#  'pubg hadir ps4 mulai desember',
#  'film siap gan akhir jadwal tayang',
#  'daftar kosmetik tak masuk kabin pesawat',
#  'optiemus rilis bb evolve evolve x pasar asia selatan',
#  'city terus dominasi atas fulham',
#  'alas perempuan selingkuh',
#  'laku bila atas kurang kompeten',
#  'sbmptn 2019 sistem utbk',
#  'anies panjang ganjilgenap warga beli mobkas',
#  'vonis rata 10 hari kasus bakar bendera garut',
#  'hampir seluruh wakil indonesia menang mudah',
#  'realisasi investasi migas meleset target',
#  'huesca 1 1 getafe la liga 2018 2019',
#  'tiga kiat cinta kerja suka',
#  '6 fakta nikah christian bautista kat ramnani kue unik',
#  'fulham 3 2 southampton epl 2018 2019',
#  'leicester city 1 1 west ham united epl 2018 2019',
#  'ulas datang blackpink jakarta rusuh gemar hingga sosok rose kw',
#  'juventus 2 0 spal liga serie a 2018 2019',
#  'tekateki jasad khashoggi cerai berai',
#  'cagliari 2 1 chievo liga serie a 2018 2019',
#  'crystal palace 0 1 wolverhampton wanderers epl 2018 2019',
#  'lemur ancam punah buru',
#  'aktivitas manusia bikin badai lebih buruk',
#  'the nun amuk tangga box office',
#  'kpk telusur sumber uang suap terima wakil ketua dpr taufik kurniawan',
#  'manusia kerdil modern flores bukan turun hobbit',
#  'persib gagal dekat psm',
#  'main emas lebih mujur ketimbang valas',
#  'kubu prabowo minta perintah ungkap aktor balik tangkap habib rizieq',
#  'adu limbah malah jadi modus suap dprd kalteng',
#  'bintang belok kanan barcelona ungkap sulit jadi anak sma',
#  'kisah tokoh utama the walking dead film',
#  'disney beku proyek guardians of the galaxy 3',
#  'orang sibuk gawai cenderung kurang bahagia',
#  'rayo vallecano 2 2 villarreal la liga 2018 2019',
#  'asi games sepi hiruk pikuk',
#  'kaldu ayam kaya kolagen kulit',
#  'fiorentina 1 1 cagliari liga serie a 2018 2019',
#  'dagang media sosial bakal kena pajak',
#  'facebook twitter google hapus ratus akun rusia iran',
#  'bangkit bulu tangkis jepang',
#  'garuda muda siap takluk qatar',
#  'bandit timpang ekonomi',
#  'akses transportasi palu mulai kondusif',
#  'yovie widianto raya usia 50 konser inspirasi cinta',
#  'fitur galaxy note 9 tampak janji pes',
#  'pavettia skincare juara the big start indonesia',
#  'manchester united 0 0 crystal palace epl 2018 2019',
#  'anwar ibrahim selang pimpin malaysia',
#  'tik tok siap ubah jadi aplikasi ramah anak',
#  'mitigasi gempa tsunami ala chili',
#  'jelas ilmiah orang seret ombak',
#  'genoa 1 1 sampdoria liga serie a 2018 2019',
#  'robot madam api indonesia go international',
#  'manfaat jaga sehat mental jelang hari nikah',
#  'lazio 0 3 inter mil liga serie a 2018 2019',
#  'ikigai konsep bahagia orang jepang',
#  'trik praktis pangkas keluar bulan',
#  'usaha rintis lahir gelisah sang diri',
#  '6 tanya jebak wawancara kerja',
#  '5 alas cari kerja baru',
#  'target tinggi timnas batu sandungan',
#  'praktik buru paus era romawi kuno musnah populasi',
#  'jadi wagub dki syaikhu kembang program oce',
#  'sulit buat film wiro sableng',
#  'menang timnas indonesia atas singapura',
#  'cabut hak politik wali kota nonaktif kendari ayah',
#  'air planet merah ilmuwan gairah',
#  'richard thaler baca ekonomi perilaku manusia',
#  'napoli 5 1 empoli liga serie a 2018 2019',
#  'canon rilis kamera mirrorless full frame eos r',
#  'rizki ketut lanjut kejut ginting tak kutik',
#  'sevilla 1 0 real valladolid la liga 2018 2019',
#  'uang muka kpr nol persen pns tahun politik',
#  'teater koma hidup kisah mahabarata asmara raja dewa',
#  'asih sempal danur film horor sedikit main',
#  'kumbang 99 juta tahun simpan ambar myanmar',
#  'hendra ahsan lengkap pulang unggul',
#  '6 tanya jebak wawancara kerja',
#  'jam tangan pintar baru garmin tara ponsel',
#  'jadi apa lima tahun',
#  'arsenal 1 1 wolverhampton wanderers epl 2018 2019',
#  'aktivis antikorupsi periksa polisi',
#  'jojo anthony tommy laju delapan besar',
#  'seru edy rahmayadi balik gagal timnas indonesia',
#  'tumbuh ekonomi balik prestasi atlet',
#  'sela jauh zona degradasi sriwijaya dekat',
#  'pamor snapchat jauh bawah instagram',
#  'ingat alat deteksi dini tsunami',
#  'empoli 3 2 atalanta liga serie a 2018 2019',
#  'sevilla 2 1 espanyol la liga 2018 2019',
#  'negosiasi kabar buntu korut mulai marah as',
#  'sama milik orang produktif',
#  'jelas baru misteri segitiga muda',
#  'kerak bumi simpan triliun ton berlian',
#  'west ham united 4 2 burnley epl 2018 2019',
#  'tahu tingkat obesitas citra satelit',
#  'pandu capai bahagia 7 hari',
#  'atalanta 4 1 inter mil liga serie a 2018 2019',
#  'upaya redam dampak insiden bakar bendera garut',
#  'upaya nasa sentuh lapis panas matahari',
#  'watford 3 0 huddersfield town epl 2018 2019',
#  'stigma negatif anak idap hiv larang sekolah',
#  'everton 3 1 brighton hove albion epl 2018 2019',
#  'audit bpk seret sengketa aset kemenpora vs roy suryo',
#  'bantah cerai rekayasa charly juang kejar regina minggat rumah',
#  'empoli 1 2 juventus liga serie a 2018 2019',
#  'timbang usaha lama',
#  'ajar harga timnas u19 pascakalah arab',
#  'southampton 0 3 chelsea epl 2018 2019',
#  'delapan badak hitam kenya mati duga akibat dehidrasi',
#  'masa suram italia lanjut',
#  'real betis 3 3 celta de vigo la liga 2018 2019',
#  'persiba krisis dana stadion bata merana',
#  'lebih 50 persen keluar rumah tangga milenial habis makan',
#  '5 500 lari ramai relay marathon pertama indonesia',
#  'sriwijaya jaga jarak zona degradasi',
#  'deportivo alaves 2 1 huesca la liga 2018 2019',
#  'peluang kevin marcus jadi main baik 2018 buka lebar',
#  '7 kiat sukses magang',
#  'huesca 0 2 espanyol la liga 2018 2019',
#  'balik putus elon musk mundur tesla',
#  'src sasar ritel tradisional jadi pilar ekonomi nasional',
#  '5 klub tarung jauh zona degradasi psis mulai aman',
#  'misteri hilang khashoggi tekan arab saudi',
#  'anthony temu jojo kevin marcus sua musuh lama',
#  'kongko rumah jadi kunci bahagia',
#  'tcash buka akses semua operator',
#  'binatang suka rasa pedas',
#  'oppo saji teknologi isi baterai super cepat f9',
#  'harimau punah tinggal cerita lalu mungkin lupa',
#  'proyek meikarta batu sandungan gurita bisnis lippo group',
#  'tes dna ungkap nenek moyang duduk asia tenggara',
#  'arti penting superliga junior klub',
#  'donggala kota labuh tengah duka',
#  'hakim agung suhad semangat artidjo hukum berat koruptor',
#  'fokus asuh anak putri marino tolak tawar main film',
#  'rekonstruksi dampak bencana sulteng kira butuh rp10 t',
#  'kabupaten bekas zona merah korupsi',
#  'sambut positif indonesia sport awards 2018',
#  'transisi main timnas indonesia beranta',
#  'wajah jenggot perlu awat kulit',
#  'politisasi isu pki tahun politik',
#  'isyana sarasvati wujud impi film milly mamet',
#  'uang muka kpr nol persen pns tahun politik',
#  'batas akhir daftar cpns berkas administrasi',
#  'ancam sanksi berat singa terbang',
#  'facebook luncur lasso saing tik tok',
#  'polda metro kerah 1 812 polantas lancar tutup asi games 2018',
#  'totalitas transformasi fisik christian bale',
#  'bin tegas tak libat periksa rizieq polisi arab saudi',
#  'kering landa jawa barat nusa tenggara',
#  'real valladolid 0 0 eibar la liga 2018 2019',
#  'langit cerah lap kampanye malam lampu',
#  'apa putus the fed pengaruh',
#  'deret film indonesia tayang november 2018',
#  'nurhadi pusar kasus eddy sindoro',
#  'rosmah mansor 17 kasus cuci uang hindar pajak',
#  'tepat minta naik gaji',
#  'lawan rasa betah kantor baru',
#  'cokelat jadi alih hati jaring gemar baru',
#  'mu rasa tandang old trafford',
#  'kalah arema persib langsung tatap borneo fc',
#  'waktu makan anak pengaruh tumbuh kembang optimal',
#  '4 dampak buruk jadi orang workaholic',
#  'leclerc ganti raikkonen ferrari musim depan',
#  'lemah rupiah pengaruh inflasi',
#  'warna tua dunia merah muda',
#  'kolaborasi bts aoki buka jalan musisi',
#  'segel tiga gereja kota jambi',
#  'lawan irwandi yusuf kandas praperadilan',
#  'afair lebih bahagia perempuan',
#  'tak proposal aju utang bal',
#  'api gunung ciremai abang padam merbabu bara',
#  'dinamika pasar uang tinggi',
#  'punya keluarga besar turun potensi kena kanker',
#  'xiaomi bawa smart tv indonesia harga 1 9 juta',
#  'knkt mesin pesawat lion air hidup jatuh laut',
#  'timo tjahjanto pukau the night comes for us',
#  'beli orang duit',
#  'tulis to do list ala ivy lee',
#  'waktu pakai deodoran pengaruh bau badan',
#  'lima wakil indonesia masuk empat final',
#  'jalan eko yuli olimpiade 2020 awal emas rekor',
#  'beban semangat fajar bustomi garap dil 1991',
#  'hadap gejolak ekonomi global',
#  'breaking bad jadi film panjang',
#  'kevin marcus lolos final',
#  'undi berat wakil indonesia babak awal',
#  'emas suparniyati ibunda rica pecah rekor asia',
#  'lestari hiu paus bantu kembang ekowisata indonesia',
#  'korsel ajak korut jadi tuan rumah sama olimpiade 2032',
#  'taufik jadi sangka amien rais tak gubris',
#  'bulan mungkin pernah huni makhluk hidup',
#  'ragam sulit terpa main wiro sableng',
#  'donggala isolasi bantu berangkat semua jalur',
#  'teliti temu cara buat fosil sintetis',
#  'kpk henti proyek bangun meikarta',
#  'raih dana rp58 triliun inalum siap tebus saham freeport',
#  'realisasi investasi lambat jelang tahun politik',
#  'oppo tampil beda find x',
#  'junjung tinggi nama bung hatta kampanye bhaca',
#  'hand sanitizer lemah lawan kuman',
#  'asah 23 atlet cilik jadi juara dunia',
#  'southampton 0 0 newcastle united epl 2018 2019',
#  'masyarakat imbau abai hoaks soal palu donggala',
#  'marc marquez deret rekor',
#  'festival kebaji tampil agam inovasi filantropi',
#  'marlina siap tarung ajang oscar 2019',
#  'usaha masalah banyak alam',
#  'real sociedad 0 1 valencia la liga 2018 2019',
#  'polisi tangkap sebar hoaks jarah',
#  'liverpool 0 0 manchester city epl 2018 2019',
#  'overlord turut kritikus',
#  'arang bambu lirik bagai bahan baku baterai',
#  'olahraga benar turun berat badan',
#  'indonesia u19 kalah yordania kurang fokus',
#  'suzanna potensi kalah abdi setan',
#  'bukti barcelona messi tak',
#  'tottenham hotspur 0 1 manchester city epl 2018 2019',
#  'gempa donggala segel gereja hingga hoaks ratna',
#  'panas global picu perang manusia vs serangga',
#  'bupati rendra sangka malang malang raya',
#  'google duga bakal rilis pixel 3 versi murah',
#  'keponakan setya novanto tuntut 12 tahun penjara',
#  'timo tjahjanto siap garap film si buta gua hantu',
#  'tujuh bidadari bungkus kisah sahabat cerita horor',
#  'honor 8x sketsa hewan tua kaltim cara piramida bangun',
#  'rayo vallecano 1 1 athletic club la liga 2018 2019',
#  'bisnis cetak time inc bidik yahoo',
#  'penting resign cara hormat',
#  'laku culi 3 warga medan tangkap salah satu polisi',
#  'atletico madrid 1 1 barcelona la liga 2018 2019',
#  'lirik sempat bisnis digital masa depan',
#  'bagaimana hadap phk',
#  'kepala daerah himpitan kampanye',
#  'berapa sering perempuan cukur rambut ketiak',
#  'valencia 1 1 leganes la liga 2018 2019',
#  'jaring investor kecil surat utang ritel',
#  'cska moscow sukacita madrid derita',
#  'mesin boeing 737 max pernah masalah',
#  'selang kevin marcus tahan gelar',
#  'han zhou jadi lawan berat kevin marcus',
#  'besar anak mental kuat',
#  'teror bom yakin tak pengaruh hadap ekonomi',
#  'kering lamongan lanjut luas',
#  'air mars hingga tisu basah organik karya siswi indonesia',
#  'kiat jaga sehat lingkung',
#  'hajar sela kans persija juara tetap buka',
#  'anna sophanah mundur dinasti politik indramayu runtuh',
#  'leganes 1 0 deportivo alaves la liga 2018 2019',
#  'sukuk wakaf tunai bantu distribusi zakat mandiri',
#  'kiat atas fomo',
#  'liverpool 4 1 cardiff city epl 2018 2019',
#  'kronologi vicky prasetyo gerebek rumah angel lelga',
#  'aktivitas situbondo langsung normal pascagempa 6 0 sr',
#  'bekas terap layan online urus dokumen duduk',
#  'the rain raya ultah ke17 bioskop hujan',
#  'pda palm bakal bangkit kubur',
#  'adaptasi atas cuek kantor baru',
#  'soputan erupsi warga perlu ungsi',
#  'barcelona sevilla rebut singgasana',
#  'milenial tak ragu investasi',
#  'as siap larang teknologi huawei zte',
#  'mahasiswa indonesia ikut andil olah tinja manusia',
#  'aremania larang hadir stadion akhir musim',
#  'ubah jadi usia 30an',
#  'newcastle united 2 1 afc bournemouth epl 2018 2019',
#  'semangat lipat borneo fc hadap persib',
#  'sampo bayi lebih lembut',
#  'lini depan jadi masalah mil',
#  'trik praktis pangkas keluar bulan',
#  'sampdoria 1 4 torino liga serie a 2018 2019',
#  'tanda tak bahagia tempat kerja',
#  'pubg ps4 misteri benua kuno hingga temu mumi',
#  'inspirasi bisnis dunia digital',
#  'internazionale 2 0 cagliari liga serie a 2018 2019',
#  'catat sensasional kevin marcus pascajuara fuzhou',
#  'ajaib dunia ke8 hilang lama',
#  'udinese 0 1 mil liga serie a 2018 2019',
#  'film generasi micin menep anggap negatif hadap gen z',
#  'upaya lifelike pictures rahasia wiro sableng',
#  'cerdas buat mampu tiru sidik jari manusia',
#  'napoli 0 0 chievo liga serie a 2018 2019',
#  '6 tanya jebak wawancara kerja',
#  'orang utan sumatra cerita soal masa lalu']

# %%
norm_test_corpus
# Out:
# ['kini ai baca pribadi orang lalu gera mata',
#  'dokumentasi karier coldplay a head full of dreams',
#  'serah kaya sarita abdul mukti sumber kaya faisal harris sebut usaha kaya raya',
#  'minimal risiko timbul libur asuransi jalan',
#  'rock and roll dampak negatif ekosistem',
#  'real madrid 1 2 levante la liga 2018 2019',
#  'evakuasi harimau sumatera kian langka populasi',
#  'isu senjata kimia arab saudi balik mati khashoggi',
#  'kunci sukses tenang',
#  'model bisnis 7eleven perlu jadi ajar',
#  'orang indonesia butuh edukasi soal sampah plastik',
#  'mahasiswa unair cipta alat pantau gagal jantung',
#  'citra kirana coba genre horor lewat asih',
#  'sulit kerja status lulus smk',
#  'blackpink tampil singkat sentul',
#  'joker baru versi joaquin phoenix ungkap',
#  'internet ancam naik muka laut',
#  'the negotiation jalan runding a lot',
#  'komodo phinisi hingga masyarakat difabel upacara buka',
#  'usaha ritel sayang kurang koordinasi perintah',
#  'empoli 2 1 udinese liga serie a 2018 2019',
#  'pulih ekonomi lombok pascagempa',
#  '5 sikap batal promosi',
#  'jojo lolos ginting adang',
#  'kejar bahagia bahagia',
#  'kontroversi kampanye negatif ala sohibul iman',
#  'garagara tambora napoleon kalah',
#  'kisruh honor balik megah tari buka asi games',
#  'raisa dipha barus lahir my kind of crazy',
#  'atletico madrid 2 0 real sociedad la liga 2018 2019',
#  'alami syok berat 1 korban bencana sulteng tinggal makassar',
#  'blackbery key2 le lapor bakal debut lin',
#  'serial game of thrones segera akhir',
#  'dampak ekonomi asi games sesuai harap',
#  'timnas indonesia mungkin besar punya latih baru',
#  'timnas singkir pssi tuding bagai biang keladi',
#  'bima sakti pantas percaya tangan timnas senior',
#  'teknik baru ai prediksi tumbuh kanker',
#  'terima zakat tingkat ekonomi jadi target',
#  'torino 1 1 fiorentina liga serie a 2018 2019',
#  'politis demokrat komunikasi prabowosandi efektif undang perhati publik',
#  'kenal hangnail masalah kuku kerap anggap remeh',
#  'anthony ginting akhir 24 tahun tunggal putra',
#  'lewat optimistis dampak buruk',
#  'crazy rich asians pimpin box office',
#  'indonesia gagal aff beach soccer 2018',
#  'everton 1 0 cardiff city epl 2018 2019',
#  'gera terorisme tanjungbalai muncul',
#  'tki asal madura bebas ancam hukum mati malaysia',
#  'kisah xmen lanjut dark phoenix',
#  'jaga kurs rupiah rawat fundamen ekonomi',
#  'lazio 1 1 mil liga serie a 2018 2019',
#  'afc bournemouth 0 0 southampton epl 2018 2019',
#  'investor ragu adb turun proyeksi tumbuh ekonomi',
#  'cicil setya novanto rugi negara akibat korupsi',
#  'landa banjir longsor ekonomi didik 2 desa tasikmalaya lumpuh',
#  'espanyol 1 0 athletic club la liga 2018 2019',
#  'indonesia dominasi ekonomi global 2050',
#  'cara ampuh tangan karyawan pasif',
#  'hadap dilema karier passion',
#  'rekayasa bakteri e coli cipta replika mona lisa',
#  'target mrt tahap ii rampung 2025 operasi 2027',
#  'villarreal 0 1 real valladolid la liga 2018 2019',
#  'buah spbu jember ludes bakar',
#  'emile smithrowe bintang baru arsenal',
#  'amazon matang rencana ekspansi indonesia',
#  'uji tahan ekonomi',
#  'tujuh korban lion air jt610 hasil identifikasi',
#  'jeda waktu gempa tsunami enam menit',
#  'uap jangan tahan',
#  'raih capai ganda indonesia tantang korsel',
#  'chelsea 1 1 liverpool epl 2018 2019',
#  'indonesia angkat isu bencana temu bal',
#  'kpk gencar tuntut cabut hak politik jabat korupsi',
#  'soal huni dp 0 persen asn timses jokowi bantah tiru program anies',
#  'sangka dobel lawan irwandi yusuf',
#  'kemenlu atur alur masuk bantu internasional',
#  'pesta tak ganggu performa lewis hamilton',
#  'dpr bahas 12 ruu baru 2019',
#  'google maps tunjuk bumi bulat bukan datar',
#  'gugat hadap bambang hero lindung saksi ahli',
#  'paus sperma jadi inspirasi militer samar komunikasi rahasia',
#  'jual mahal jalan hubung',
#  'kota palu mulai bersih',
#  'fenomena kpop jadi alas black eyed peas kolaborasi cl',
#  'kambing suka manusia senyum',
#  'tunjuk jadi komandan jk gerak cepat',
#  'galaxy note 9 iphone x mana lebih unggul',
#  'ganda putra satu tiket final',
#  'wajah baru portugal kalah polandia',
#  'alas google investasi gojek',
#  'modric akhir dominasi messi ronaldo',
#  'korupsi khianat tugas pajak ambon',
#  'transfer uang mudah pindai kode qr',
#  'venezuela tuju titik nadir',
#  'tampil nagini ujung kontroversi',
#  'real sociedad 0 0 girona la liga 2018 2019',
#  'menang atlet sejarah indonesia dominasi tiongkok',
#  'afc bournemouth 2 1 crystal palace epl 2018 2019',
#  'adiksi ponsel orang tua buat anak bandel',
#  'udinese 0 3 napoli liga serie a 2018 2019',
#  'orang sibuk gawai cenderung kurang bahagia',
#  'katy perry rehat dunia musik',
#  'usaha masalah banyak alam',
#  'sampah jakarta bekas jangan cuma tutup hidung',
#  'asuh tidur samping anak ardi bakrie langsung lapor nia ramadhani begini tulis',
#  'yogyakarta relatif sadar ancam bencana sulteng balik',
#  'jumlah iphone x macbook pro 13 inci alami cacat produk',
#  'twitter kunci akun deteksi ubah perilaku',
#  'pertama 11 tahun el clasico messi ronaldo',
#  'alas penting biaya asuransi bencana',
#  'rp50 juta bangun buah rumah tahan gempa',
#  'afc bournemouth 1 2 arsenal epl 2018 2019',
#  'peristiwa punah massal pengaruh agam hiu',
#  'alfian gischa juara taiwan tai tzu masuk klub jutawan',
#  'watford 0 3 liverpool epl 2018 2019',
#  'ingat 10 ribu jam pacar pacar bule beri hadiah romantis buat cinta laura',
#  'empat tim kuasa delapan tanding semifinal',
#  'edar chat aku angel lelga pasca gerebek benar jebak vicky prasetyo',
#  '500 hari serang hadap novel baswedan',
#  'generasi milenial cuek hadap politik',
#  'harap pulih ekonomi paket bijak',
#  'juventus 1 1 genoa liga serie a 2018 2019',
#  'raya seni dkj fest 2018',
#  'valencia 3 0 rayo vallecano la liga 2018 2019',
#  'sukses karier metode smart',
#  'menang sulit bhayangkara fc atas seru',
#  'kaya orang dunia mulai pulih pascakrisis 2008',
#  'kontingen indonesia benar peleset atas',
#  'hanum rangga realita konflik karier rumah tangga',
#  'seteru via vallen superman is dead selesai',
#  'hasil sempurna chelsea liverpool panas awal musim',
#  'lapor uang perintah 2015',
#  'chelsea 3 1 crystal palace epl 2018 2019',
#  'eibar 1 1 athletic club la liga 2018 2019',
#  'jilbab judo larang ijf bahaya',
#  'leicester city 0 0 burnley epl 2018 2019',
#  'bologna 0 0 fiorentina liga serie a 2018 2019',
#  'definisi kilogram ubah',
#  'makin sedikit waktu tidur makin pendek umur',
#  'kisah acha septriasa lima kali peran hanum rais',
#  'eibar 2 1 deportivo alaves la liga 2018 2019',
#  '3 alas lamar takut negosiasi gaji',
#  'rayo vallecano 1 2 getafe la liga 2018 2019',
#  'timnas u16 henti tebar potensi',
#  'sriwijaya baya cetak rekor',
#  'google larang aplikasi tambang cryptocurrency play store',
#  'liverpool 2 0 fulham epl 2018 2019',
#  'reward padan usaha',
#  'falcon film crazyrichsurabayan',
#  'bahaya minum air rebus balut',
#  'tinggal 5 biasa cari kerja',
#  'besar sektor hijau ihsg tutup naik',
#  'reward padan usaha',
#  '23 atlet muda raih djarum beasiswa bulutangkis 2018',
#  'alfacart siap program mudik bantu modal ukm',
#  'jauh keluarga dekat bau anyir',
#  'tontontan tarik ala djanur balik menang telak baya',
#  'psikolog anak tak usah ajak luar negeri',
#  'anthonius gunawan agung nobat bagai pahlawan terbang',
#  'terbit obligasi bawa posisi utang luar negeri naik',
#  'daud yordan kalah crolla beri kredit khusus',
#  'ganda campur dominasi empat final nomor tunggal rontok',
#  'bohemian rhapsody pimpin tangga film laris',
#  'android pie hadir bagai fitur bas ai',
#  'kejut banksy rajang lukis rp20 m sothebys',
#  'temu burung unik hasil hibrida tiga spesies beda',
#  'muse hadir nuansa 1980an simulation theory',
#  'raya batik film pendek sekar',
#  'banjir tasikmalaya waspada curah hujan tinggi',
#  'bank dunia revisi tumbuh ekonomi indonesia',
#  'indonesia sempurna laga awal',
#  'lampard lawan chelsea sanjung kalah',
#  'tiru tiru karya seni',
#  'anggap hama serangga nyata bantu serbu',
#  'watford 0 4 afc bournemouth epl 2018 2019',
#  'newcastle united 0 1 brighton hove albion epl 2018 2019',
#  'yahya fuad pidana korupsi cabut hak politik',
#  'fantastic beasts 2 tak sesuai harap tetap laris',
#  'athletic club 1 1 getafe la liga 2018 2019',
#  'andi narogong bayar uang ganti',
#  'atalanta 3 0 parma liga serie a 2018 2019',
#  'kenal kiat atas stres psikososial',
#  'real betis 0 1 real valladolid la liga 2018 2019',
#  'kevin marcus dekat rekor baru',
#  'tim indonesia wajib waspada tengah hasil sempurna',
#  'arab saudi akhir umum khashoggi bunuh istanbul',
#  'critical eleven wakil indonesia aaa 2018',
#  'james gunn garap suicide squad 2',
#  'temu spesies baru dinosaurus ubah sejarah awal',
#  'indonesia raih gelar malaysia international series',
#  'persib kalah gomez umuh marah',
#  'disney incar oscar black panther',
#  'besar santun keluarga korban insiden lion air',
#  'belanja wisatawan asi games lampau kira',
#  'peti mayat granit hitam besar temu mesir',
#  'masyarakat mulai muak hoaks',
#  'akun facebook instagram bawah 13 tahun bakal tutup paksa',
#  'rayo vallecano 2 2 espanyol la liga 2018 2019',
#  'sevilla 2 1 huesca la liga 2018 2019',
#  'paus lumbalumba jam tangan pintar garmin hingga burung kicau',
#  'persib tahan seru gomez anggap untung',
#  'klub asing jadi bulan klub lokal',
#  'facebook nyu garap mri bas ai',
#  'ecek data miskin rujuk prabowo',
#  'kasus idiot polisi toleransi tiga hari dhani datang 3 saksi ahli',
#  'sosialisasi panjang ganjil genap usai asi games mulai hari',
#  'ponsel layar lipat jadi tren 2019',
#  'getafe 2 0 real betis la liga 2018 2019',
#  'pasar kramat jati kini predikat sehat',
#  'huddersfield town 1 1 west ham united epl 2018 2019',
#  'kesal mourinho makin cecer mu',
#  'presiden jokowi agenda temu putin sela ktt asean',
#  'ekonomi pancasila ala presiden jokowi',
#  'istimewa suara freddie mercury',
#  'beras rekayasa genetika netral hiv',
#  'cara asus incar pasar laptop milenial',
#  'nobel teori interaksi ekonomi alam teknologi',
#  '5 salah kerap laku interview kerja',
#  'proyek ramah lingkung indonesia lirik investor asing',
#  'dobrak batas tani harum tembakau kudus relay marathon',
#  'liverpool buang peluang belgrade',
#  'persib unggul lima angka puncak klasemen',
#  'tiga lokasi timbang jadi rumah baru ungsi',
#  'raisa tuju lembar baru',
#  'kpk siap kawal kasus korupsi lahan libat nur mahmud',
#  'infrastruktur palu baik tanggap darurat usai pekan',
#  'aktivitas kota palu mulai geliat',
#  'kala persib curi poin jayapura',
#  'gempa ungkap kuil kuno piramida meksiko',
#  'ekspedisi palukoro ingat gempa abai',
#  'cegah dendam ubah fatal',
#  'wakil indonesia nyaris sempurna babak tiga',
#  'nobel damai 2018 juang jahat perang',
#  'sahabat maria ozawa sebut tugas imigrasi ikut mabuk acara ultah',
#  'garuda muda toreh sejarah baru',
#  'kota palu donggala lumpuh',
#  'timpang ekonomi jadi dorong selfie seksi',
#  'kompak tampil perdana blackpink sambut histeris gemar',
#  'rizieq periksa polisi arab saudi kasus tahu',
#  'ucap belasungkawa mendiang stan lee abadi internet',
#  'spurs fantastis hadir kalah pertama chelsea',
#  'angel lelga riak warga gerebek nyata fakta',
#  'efek balita main gadget nyata tak buruk',
#  'perintah poles 3 destinasi wisata banyuwangi',
#  'napas kubur kisah baru suzanna',
#  'villarreal 1 1 atletico madrid la liga 2018 2019',
#  'ralph breaks the internet uji sahabat',
#  'girona 0 1 real betis la liga 2018 2019',
#  'sulit temu karier impi',
#  'crystal palace 2 2 arsenal epl 2018 2019',
#  'puan maharani minta rehabilitasi lombok cepat',
#  '5 alas usaha rekrut lulus baru',
#  'bulu tangkis sumbang emas pertama ni nengah raih perak',
#  'jumlah anggur desa naik kota turun',
#  'pasang tak lirik lebih tarik',
#  'arsenal 3 1 leicester city epl 2018 2019',
#  'jatuh lion air eksekusi tkw nasib wakil ketua dpr',
#  'cardiff city 0 1 leicester city epl 2018 2019',
#  'remah roti tua yordania ungkap pola makan zaman batu',
#  'tantang atlet lebih berat banding asi games',
#  'real valladolid 1 1 espanyol la liga 2018 2019',
#  'ilmuwan temu otak tekan rasa takut',
#  'kampanye bogor sandiaga janji revitalisasi pasar tradisional',
#  'psm dekat puncak persib pilih balikpapan',
#  'ingat sensor posisi 737 max pukul bisnis lion air',
#  'leganes 1 1 atletico madrid la liga 2018 2019',
#  'cerdik pellegrino lahir kalah pertama barcelona',
#  'kabar meni diam kata sule',
#  'cara senang cari inspirasi bisnis',
#  'liga 1 henti perintah hati',
#  'satu hindar karyawan baru',
#  'fosil pterodactyl usia 200 juta tahun temu gurun utah',
#  'beli apartemen harga rp 26 miliar jin bts tetap tinggal asrama',
#  'timnas senior janji cekat',
#  'menang arsenal rapuh',
#  'arsenal tak pernah menang liverpool sejak 2015',
#  '5 alas kerja tak pernah selesai',
#  'balap asal depok turun moto2 musim depan',
#  'house with a clock puncak box office pekan sepi',
#  'tarung spesial daud yordan manchester',
#  '90 detik pertama wawancara',
#  'persija akhir 16 tahun dahaga gelar',
#  'gp valencia tutup musim motogp penuh drama',
#  'beda samsung galaxy a9 galaxy a7',
#  'prabowo janji setop impor timses jokowi sebut cuma retorika belaka',
#  'diam tahu gaji bos picu semangat kerja',
#  'manusia purba punah malas',
#  'ilmuwan temu otak tekan rasa takut',
#  'bahaya micromanagement tempat kerja',
#  'guntur soeharjanto bicara soal belok kanan barcelona',
#  'jawab ramal krisis ekonomi 2020',
#  'gagal taktik hambat langkah bal united',
#  'balas dendam marquez thailand',
#  'naik setor google apple',
#  'bila salah pilih tempat kerja baru',
#  'mil 2 1 genoa liga serie a 2018 2019',
#  'ma kabul gugat oesman sapta',
#  'indonesia cipta sepeda kayu listrik pertama dunia',
#  'rencana google tiongkok resah jumlah pihak',
#  'propaganda iran rusia kamera nikon hingga temu air bulan',
#  'barcelona catat episode negatif madrid mulai bangkit',
#  'banjir liput aceh',
#  'xiaomi hadir pocophone f1 flagship killer baru',
#  'lihat ancam hilang sinar biru ponsel',
#  'tottenham hotspur 1 0 cardiff city epl 2018 2019',
#  'zumi zola jadi gubernur jambi mau ayah',
#  'cara senang cari inspirasi bisnis',
#  'parma 2 1 sassuolo liga serie a 2018 2019',
#  'joko anwar garap proyek tiga film lokal rasa internasional',
#  'pemkab bekas benah rumah ceo lippo group geledah',
#  '20 tahun penjara milik pabrik miras oplos maut',
#  'kiat aman nyaman belanja daring',
#  'bukti hailey baldwin justin bieber resmi meni',
#  'mil 3 2 sampdoria liga serie a 2018 2019',
#  'optimisme persib bumi borneo',
#  'olahraga benar turun berat badan',
#  'ernest prakasa kawan ramai film sesuai aplikasi',
#  'fulham 1 5 arsenal epl 2018 2019',
#  'hindar undur diri 5 alas',
#  'ifa lin pocophone f1 hingga pltp ulumbu ntt',
#  '4 kontroversi via vallen naik turun bintang dangdut koplo',
#  'pengaruh gaya pimpin hadap turnover karyawan',
#  'perlu perhati transformasi bisnis digital',
#  'luhut tak lebih bal',
#  '5 sektor seret lemah ihsg',
#  'bangun geometrik baru tubuh manusia',
#  'penuh panggil kpk 22 anggota dprd malang tolak jakarta',
#  'manajemen sampah zero ubah sampah jadi nila',
#  'korupsi 12 kepala daerah solusi khofifah',
#  'sejarah balik selenggara asi games',
#  'elsa atlet indonesia pertama rebut emas boling',
#  'indonesia pimpin adopsi ai asia tenggara',
#  'celta de vigo 2 4 real madrid la liga 2018 2019',
#  'bising lalulintas pendek umur burung',
#  'prestasi apik skuat indonesia tebal asa denmark',
#  'indonesia pulang tangan hampa',
#  'barcelona 1 1 athletic club la liga 2018 2019',
#  'ekonomi politik esemka',
#  'sihir guns n roses gelora bung karno',
#  'manchester city 3 1 manchester united epl 2018 2019',
#  'getafe 0 1 valencia la liga 2018 2019',
#  'kaldu ayam kaya kolagen kulit',
#  'nikmat hidup mental sehat',
#  'penting resign cara hormat',
#  'wolverhampton wanderers 2 0 southampton epl 2018 2019',
#  'ongkos joki tes cpns capai ratus juta rupiah',
#  'spesies paus menopause manusia',
#  'banjir longsor mandailing hanyut 77 rumah',
#  'plinplan dpr minta publik dana saksi rp3 9 triliun',
#  'line buka 3 kategori baru ajang creativate 2018',
#  'timnas indonesia menang sabar',
#  'puji lin anthony ginting',
#  'jelas rasa panik candu internet tak wifi',
#  'train to bus jadi rebut studio hollywood',
#  'imbang liverpool sarri yakin chelsea lang maju',
#  'terbang antariksa siap uang rp2 8 miliar',
#  'kontroversi team order menang hamilton rusia',
#  'fantastic beasts 2 ancam waralaba harry potter',
#  'melinda gates sri mulyani satu suara soal teknologi',
#  'bologna 1 2 atalanta liga serie a 2018 2019',
#  'alas rupiah sulit kuat waktu dekat',
#  'daftar ponsel masuk sertifikasi youtube',
#  'burnley 0 4 chelsea epl 2018 2019',
#  'modus lucas lari eddy',
#  'main timnas indonesia turun benah',
#  'hiu paus nyata hidup capai umur 130 tahun',
#  'kabar kabur bantah isu suap persib',
#  'kuat dialog hari jadi andal aruna lidah',
#  'naik ump nilai buruh kurang turut usaha tinggi',
#  'eibar 1 3 sevilla la liga 2018 2019',
#  'kenal momo tara bonus atlet',
#  'juventus 3 1 cagliari liga serie a 2018 2019',
#  'liverpool city main aman chelsea amuk',
#  'night school jadi jawara box office',
#  'insiden lion air coreng selamat terbang indonesia',
#  'newcastle united 1 0 watford epl 2018 2019',
#  'kota kaltim rasa gempa',
#  'kendali turnover karyawan tinggi',
#  'eddy soeparno ajak warga nobar film adaptasi novel karya anak amien rais',
#  'fiorentina 1 1 roma liga serie a 2018 2019',
#  'gaduh bakar bendera minta maaf',
#  'hukum amen nyanyi lagu orang',
#  'frosinone 3 3 empoli liga serie a 2018 2019',
#  'sukses bisnis daring ponsel pintar tepat',
#  'jendi selamat wajah indonesia hari lima',
#  'fiorentina 2 0 atalanta liga serie a 2018 2019',
#  'serat alami jadi alternatif atas masalah sampah plastik',
#  'frosinone 1 2 genoa liga serie a 2018 2019',
#  'tip tumbuh loyalitas karyawan',
#  'usaha rongkosan aku tak tahu 60 mortir beli aktif',
#  'ikan sulit tahan hidup laut makin asam',
#  'pek operasi zebra polisi tilang 52 366 kendara',
#  'crystal palace 0 1 tottenham hotspur epl 2018 2019',
#  'benar dagang bebas indonesiaaustralia ancam isu israel',
#  'sandiaga harap partai besut yusril ihza mahendra gabung prabowo',
#  'temu dinosaurus baju besi as ungkap sejarah baru',
#  'bimbang pilih tawar kerja',
#  'tip hadap wawancara kerja tak tepat waktu',
#  'berapa harga cincin putri ana pakai kate middleton',
#  'mungkin jerat pidana sebar hoaks ratna sarumpaet',
#  'the 90s festival datang blue the moffatts',
#  'michael b jordan peran john clark ala tom clancy',
#  'alas ponsel tiongkok kian gari konsumen',
#  'untung rugi tahan kerja tak suka',
#  'meski menang timnas indonesia yakin',
#  'bologna 2 1 udinese liga serie a 2018 2019',
#  'untung rugi jadi kutu loncat',
#  'usaha move on 10 potret indro warkop tinggal sang istri',
#  'serang israel guncang rumah sakit indonesia gaza',
#  'dinamika hidup ojek online film sesuai aplikasi',
#  'baterai kertas ramah lingkung tenaga air liur',
#  'ekonomi global stagnan tumbuh ekonomi revisi',
#  'yahoo rencana jual bisnis utama',
#  'barcelona 4 2 sevilla la liga 2018 2019',
#  'kiat jaga sehat lingkung',
#  'usaha prioritas gelar alam',
#  'valencia 0 1 girona la liga 2018 2019',
#  'pindah jayapura hilang main persib tetap optimistis',
#  'rancang beladiri film wiro sableng',
#  'tip atas minder rekan kerja',
#  'whatsapp sedia kapasitas data batas google drive',
#  'asal debu planet mars kuak',
#  'espanyol 1 3 girona la liga 2018 2019',
#  'waktu baik beli asuransi',
#  'kiat tambah relasi bisnis',
#  'generasi baru timnas indonesia fokus transisi main',
#  'global pangkas tumbuh indonesia kuat bijak',
#  'tarung mayweather vs nasukawa mungkin batal',
#  'kiat maksimal facebook bisnis',
#  'staf raja inggris kan sifat asli meghan markle jadi istri pangeran harry',
#  '4 ucap sering disalahartikan lamar']

# %%
#mengunakan model TF-IDF untuk mengekstraksi feature
tfidf_vectorizer, tfidf_train_features = tfidf_extractor(norm_train_corpus)
tfidf_test_features = tfidf_vectorizer.transform(norm_test_corpus)

tokenized_train = [nltk.word_tokenize(text)
                  for text in norm_train_corpus]
tokenized_test = [nltk.word_tokenize(text)
                 for text in norm_test_corpus]

model = gensim.models.Word2Vec(tokenized_train,
                              size=500,
                              window=100,
                              min_count=30,
                              sample=1e-3)

# %%
#kami mengevaluasi model menggunakan fungsi train_predict_evaluate_model
#kami mengukur nilai accuracy,precission, recall, dan F1 score apakan nilainya sudah sesuai atau tidak. Jika nilainya mendekati 1 maka proses klasifikasi berhasil


from sklearn.linear_model import SGDClassifier

train_features=tfidf_train_features
train_labels=train_labels
test_features=tfidf_test_features
test_labels=test_labels

clf = SGDClassifier(loss='hinge', n_iter=100)
clf.fit(train_features, train_labels)
predictions = clf.predict(test_features)
    
print("Label test: " +format(test_labels[:10]))
print("Prediction test: "+ format(predictions[:10]))
print("Accuration: "+format(clf.score(test_features,test_labels)))
# Out:
# C:\Users\Grelly\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# Label test: 1148      sains-tekno
# 1049    entertainment
# 982     entertainment
# 808        gaya hidup
# 1195      sains-tekno
# 240             sport
# 1118      sains-tekno
# 596              news
# 924        gaya hidup
# 65            ekonomi
# Name: Jenis, dtype: object
# Prediction test: ['gaya hidup' 'gaya hidup' 'news' 'gaya hidup' 'news' 'sport' 'sains-tekno'
#  'news' 'gaya hidup' 'gaya hidup']
# Accuration: 0.7754629629629629

# %%
from sklearn.pipeline import make_pipeline

pipe= make_pipeline(tfidf_vectorizer,clf)
pipe.fit(train_corpus,train_labels)

print(pipe.score(test_corpus,test_labels))

tempFeature=normalize_corpus(feature)
# Out:
# C:\Users\Grelly\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# 0.777777777778

# %%
tempData=pd.DataFrame(np.column_stack([feature,label]),columns=('Feature','Label'))
tempData
tempRest = [pipe,tempData]
line = np.array(['dampak perceraian pada psikologis anak'])
pipe.predict(line)
joblibFile = "SGDClassifier-new3.pkl"
from sklearn.externals import joblib
joblib.dump(tempRest,joblibFile)
# Out:
# ['SGDClassifier-new3.pkl']

# %%
def get_metrics(true_labels, predicted_labels):
    print('Accuracy: ', np.round(metrics.accuracy_score(true_labels,
                                                     predicted_labels),2))
    print('Precision: ', np.round(metrics.precision_score(true_labels,
                                                     predicted_labels,
                                                        average='weighted'),2))
    print('Recall: ', np.round(metrics.recall_score(true_labels,
                                                     predicted_labels,
                                                        average='weighted'),2))
    print('F1 Score: ', np.round(metrics.f1_score(true_labels,
                                                     predicted_labels,
                                                        average='weighted'),2))

# mengevaluasi performa prediksi menggunakan model  
get_metrics(true_labels=test_labels,predicted_labels=predictions)

# def train_predict_evaluate_model(classifier,
#                             train_features, train_labels,
#                             test_features, test_labels):
#     #membuat model
#     classifier.fit(train_features, train_labels)

#     #melakukan prediksi menggunakan model
#     predictions = classifier.predict(test_features)
    
#     #mengevaluasi performa prediksi menggunakan model  
#     get_metrics(true_labels=test_labels,
#                predicted_labels=predictions)
#     return predictions

# from sklearn.linear_model import SGDClassifier
# from sklearn.pipeline import make_pipeline

# mnb = MultinomialNB()
# svm = SGDClassifier(loss='hinge', n_iter=100)
# pipeline = make_pipeline(tfidf_vectorizer,MultinomialNB())

# print("-------------------------------------------------------------")
# mnb_tfidf_predictions = train_predict_evaluate_model(classifier=mnb,
#                                                   train_features=tfidf_train_features,
#                                                   train_labels=train_labels,
#                                                   test_features=tfidf_test_features,
#                                                   test_labels=test_labels)
# print("-------------------------------------------------------------")
# svm_tfidf_predictions = train_predict_evaluate_model(classifier=svm,
#                                                   train_features=tfidf_train_features,
#                                                   train_labels=train_labels,
#                                                   test_features=tfidf_test_features,
#                                                   test_labels=test_labels)
# Out:
# Accuracy:  0.78
# Precision:  0.79
# Recall:  0.78
# F1 Score:  0.78

# %%
tes = dataset.iloc[174,:]
tes
